# %% [markdown]
# <a href="https://colab.research.google.com/github/Faith-Mueni/Python-Data-Analysis/blob/main/Chipotle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
""" 1. Import the necessary libraries

Step 2. Import the dataset from this address.
Step 3. Assign it to a variable called chipo.

Step 4. How many products cost more than $10.00?

Step 5. What is the price of each item?
print a data frame with only two columns item_name and item_price

Step 6. Sort by the name of the item

Step 7. What was the quantity of the most expensive item ordered?

Step 8. How many times was a Veggie Salad Bowl ordered?

Step 9. How many times did someone order more than one Canned Soda?|"""

# %%
import pandas as pd
pd.read_csv( "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep="\t")
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
#Assign it to a variable called chipo
chipo =pd.read_csv( "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep="\t")
print(chipo)
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
#How many products cost more than $10.00?
chipo['item_name'].value_counts()[chipo['item_price'] > 10]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-bffa2b441218> in <cell line: 1>()
# ----> 1 chipo['item_name'].value_counts()[chipo['item_price'] > 10]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __gt__(self, other)
#      56     @unpack_zerodim_and_defer("__gt__")
#      57     def __gt__(self, other):
# ---> 58         return self._cmp_method(other, operator.gt)
#      59
#      60     @unpack_zerodim_and_defer("__ge__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    6241
#    6242         with np.errstate(all="ignore"):
# ...

# %%
#What is the price of each item?
#print a data frame with only two columns item_name and item_price
price = chipo.iloc[:,[2,4]]
print(price)
# Out:
#                                   item_name item_price
# 0              Chips and Fresh Tomato Salsa     $2.39
# 1                                      Izze     $3.39
# 2                          Nantucket Nectar     $3.39
# 3     Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                              Chicken Bowl    $16.98
# ...                                     ...        ...
# 4617                          Steak Burrito    $11.75
# 4618                          Steak Burrito    $11.75
# 4619                     Chicken Salad Bowl    $11.25
# 4620                     Chicken Salad Bowl     $8.75
# 4621                     Chicken Salad Bowl     $8.75
#
# [4622 rows x 2 columns]

# %%
# prompt: Sort by the name of the item

chipo.sort_values('item_name',ascending=True)
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description item_price
# 3389                                        [Diet Coke]    $12.98
# 341                                         [Diet Coke]     $6.49
# 1849                                             [Coke]     $6.49
# 1860                                        [Diet Coke]     $6.49
# 2713                                             [Coke]     $6.49
# ...

# %%
# prompt: What was the quantity of the most expensive item ordered

most_expensive_item = chipo.loc[chipo['item_price'].idxmax()]
quantity = most_expensive_item['quantity']
print(f"Quantity of the most expensive item ordered: {quantity}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-2bb40aa51a4e> in <cell line: 3>()
#       1 # prompt: What was the quantity of the most expensive item ordered
#       2
# ----> 3 most_expensive_item = chipo.loc[chipo['item_price'].idxmax()]
#       4 quantity = most_expensive_item['quantity']
#       5 print(f"Quantity of the most expensive item ordered: {quantity}")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in idxmax(self, axis, skipna, *args, **kwargs)
#    2562         nan
#    2563         """
# -> 2564         i = self.argmax(axis, skipna, *args, **kwargs)
#    2565         if i == -1:
#    2566             return np.nan
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in argmax(self, axis, skipna, *args, **kwargs)
#     653             # error: Incompatible return value type (got "Union[int, ndarray]", expected
# ...

# %%
chipo.loc[:,[4]].sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-b7d5abc9e3f9> in <cell line: 1>()
# ----> 1 chipo.loc[:,[4]].sort_values(ascending=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1254             return self._multi_take(tup)
#    1255
# -> 1256         return self._getitem_tuple_same_dim(tup)
#    1257
#    1258     def _get_label(self, label, axis: int):
#
# ...

# %%
#What was the quantity of the most expensive item ordered
chipo.sort_values('item_price',ascending=False)
# Out:
#       order_id  quantity            item_name  \
# 2624      1042         1     Steak Salad Bowl
# 4419      1762         1     Steak Salad Bowl
# 4036      1615         1     Steak Salad Bowl
# 1825       738         1  Barbacoa Salad Bowl
# 3115      1243         1  Carnitas Salad Bowl
# ...        ...       ...                  ...
# 3145      1254         1          Canned Soda
# 414        180         1          Canned Soda
# 3162      1262         1          Canned Soda
# 821        338         1          Canned Soda
# 1457       591         1          Canned Soda
#
#                                      choice_description item_price
# 2624  [Fresh Tomato Salsa, [Black Beans, Sour Cream,...     $9.39
# 4419  [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $9.39
# 4036  [Fresh Tomato Salsa, [Fajita Vegetables, Chees...     $9.39
# 1825  [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...     $9.39
# 3115  [Tomatillo Green Chili Salsa, [Rice, Pinto Bea...     $9.39
# ...

# %%
# prompt: What was the quantity of the most expensive item ordered

most_expensive_item = chipo.loc[chipo['item_price'].idxmax()]
quantity = most_expensive_item['quantity']
print(f"Quantity of the most expensive item ordered: {quantity}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-2bb40aa51a4e> in <cell line: 3>()
#       1 # prompt: What was the quantity of the most expensive item ordered
#       2
# ----> 3 most_expensive_item = chipo.loc[chipo['item_price'].idxmax()]
#       4 quantity = most_expensive_item['quantity']
#       5 print(f"Quantity of the most expensive item ordered: {quantity}")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in idxmax(self, axis, skipna, *args, **kwargs)
#    2562         nan
#    2563         """
# -> 2564         i = self.argmax(axis, skipna, *args, **kwargs)
#    2565         if i == -1:
#    2566             return np.nan
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in argmax(self, axis, skipna, *args, **kwargs)
#     653             # error: Incompatible return value type (got "Union[int, ndarray]", expected
# ...

# %%
#What was the quantity of the most expensive item ordered
#prices=chipo['item_price'].sort_values(ascending=False)
max_price = chipo.loc[:, 'item_price'].max()
Quantity = max_price[9.39]
print(Quantity)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-ab0b2ccba00b> in <cell line: 4>()
#       2 #prices=chipo['item_price'].sort_values(ascending=False)
#       3 max_price = chipo.loc[:, 'item_price'].max()
# ----> 4 Quantity = max_price [9.39]
#       5 print(Quantity)
#       6
#
# TypeError: string indices must be integers

# %%
most_expensive_item = chipo.loc['item_price'].idxmax()
print(most_expensive_item)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-7d2d16162e7b> in <cell line: 1>()
# ----> 1 most_expensive_item = chipo.loc['item_price'].idxmax()
#       2 print(most_expensive_item)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1310         # fall thru to straight lookup
#    1311         self._validate_key(key, axis)
# -> 1312         return self._get_label(key, axis=axis)
#    1313
#    1314     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ...

# %%
#How many times was a Veggie Salad Bowl ordered
X_times=chipo['item_name'].value_counts()['Veggie Salad Bowl']
print("veggie_salad_bowl_count",X_times)
# Out:
# veggie_salad_bowl_count 18

# %%
#How many times did someone order more than one Canned Soda?
